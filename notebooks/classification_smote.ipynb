# %%
# Grupos de meta-variáveis por combinação. Meta-variáveis que obtiveram p-valor > 0.001 foram removidas e as repetidas entre grupos são removidas nas combinações.
## Grupo 1: Pathos, Ethos e Logos
g1_att = ['total_pos_w', 'total_pos_jj', 'total_pos_nn',
          'total_neg_w', 'total_neg_jj', 'total_neg_nn',
          'has_passive',
          'pos_sentiment_polarity', 'neu_sentiment_polarity', 'neg_sentiment_polarity', 'comp_sentiment_polarity',
          'pronoun_sent', 'future_tense',
           'has_period', 
          'has_wh', 'subjecitivity', 'conditional',
          'numerical_nominal', 'organization_named', 'person_named',
          'has_complex_sent', 'sum_log_sent', 'third_p_count'
       ]
## Grupo 2: Analise de sentimento e discurso de Ódio
g2_att = ['total_pos_w', 'total_pos_jj', 'total_pos_nn', 'total_neg_w',
       'total_neg_jj', 'total_neg_nn',  'total_pos_vb',
        'total_neg_vb',
       'hate_speech_terms_total', 
       'total_hate_jj', 'total_hate_nn', 'total_hate_rb', 'total_hate_vb']
## Grupo 3: Estatísticas do estilo de texto
g3_att = ['total_of_sentences',
       'char_mean_sentence', 'char_variance_sentence', 'total_char_text',
        'char_variance_word', 'punctuation_frequency',
       'upper_case_frequency', 'lemma_per_token']
## Grupo 4: Contexto de negação
g4_att = ['total_negation_words', 'total_negated_context']

## Grupo 1 + Grupo 2: Aristotélico e sentimento específico de ódio
att_1_2 = [ # g2
    'total_pos_w', 'total_pos_jj', 'total_pos_nn', 'total_neg_w',
       'total_neg_jj', 'total_neg_nn',  'total_pos_vb',
        'total_neg_vb',
       'hate_speech_terms_total', 
       'total_hate_jj', 'total_hate_nn', 'total_hate_rb', 'total_hate_vb',
       # g1
        'pos_sentiment_polarity', 'neu_sentiment_polarity', 'neg_sentiment_polarity',
       'comp_sentiment_polarity',
       'pronoun_sent', 'future_tense',
        'has_wh', 'subjecitivity', 'conditional',
       'numerical_nominal', 'organization_named', 'person_named',
       'has_complex_sent', 'sum_log_sent', 'third_p_count', 'has_passive',
       'has_period'
]
## Grupo 1 + Grupo 3: Aristotélico e estatísticas do estilo de texto
att_1_3 = [# g3
    'total_of_sentences',
       'char_mean_sentence', 'char_variance_sentence', 'total_char_text',
        'char_variance_word', 'punctuation_frequency',
       'upper_case_frequency', 'lemma_per_token',
    # g1
    'total_pos_w', 'total_pos_jj', 'total_pos_nn', 'total_neg_w',
       'total_neg_jj', 'total_neg_nn',
       'has_passive',
        'pos_sentiment_polarity', 'neu_sentiment_polarity', 'neg_sentiment_polarity',
       'comp_sentiment_polarity',
       'pronoun_sent', 'future_tense',
        'has_wh', 'subjecitivity', 'conditional',
       'numerical_nominal', 'organization_named', 'person_named',
       'has_complex_sent', 'sum_log_sent', 'third_p_count', 
       'has_period'
]
## Grupo 1 + Grupo 4: Aristotélico e contexto de negação
att_1_4 = [ #g1
    'total_pos_w', 'total_pos_jj', 'total_pos_nn', 'total_neg_w',
       'total_neg_jj', 'total_neg_nn',
        'pos_sentiment_polarity', 'neu_sentiment_polarity', 'neg_sentiment_polarity',        
       'comp_sentiment_polarity',
       'pronoun_sent', 'future_tense',
        'has_wh', 'subjecitivity', 'conditional',
       'numerical_nominal', 'organization_named', 'person_named',
       'has_complex_sent', 'sum_log_sent', 'third_p_count', 'has_passive',
       'has_period',
       #g4
       'total_negation_words', 'total_negated_context'
       ]
## Grupo 2 + Grupo 3: Analise de sentimento, discurso de ódio, estatísticas do estilo de texto
att_2_3 = [ # g2
    'total_pos_w', 'total_pos_jj', 'total_pos_nn', 'total_neg_w',
       'total_neg_jj', 'total_neg_nn',  'total_pos_vb',
       'total_neg_vb',
       'hate_speech_terms_total', 
       'total_hate_jj', 'total_hate_nn', 'total_hate_rb', 'total_hate_vb',
       # g3
       'total_of_sentences',
       'char_mean_sentence', 'char_variance_sentence', 'total_char_text',
        'char_variance_word', 'punctuation_frequency',
       'upper_case_frequency', 'lemma_per_token'
]
## Grupo 2 + Grupo 4: Analise de sentimento, discurso de ódio e contexto de negação
att_2_4 = [ # g2
    'total_pos_w', 'total_pos_jj', 'total_pos_nn', 'total_neg_w',
       'total_neg_jj', 'total_neg_nn', 'total_pos_vb',
        'total_neg_vb',
       'hate_speech_terms_total', 
       'total_hate_jj', 'total_hate_nn', 'total_hate_rb', 'total_hate_vb',
       # g4
       'total_negation_words', 'total_negated_context'
]
## Grupo 3 + Grupo 4: Estatísticas do estilo de texto e contexto de negação
att_3_4 = [# g3
    'total_of_sentences',
       'char_mean_sentence', 'char_variance_sentence', 'total_char_text',
        'char_variance_word', 'punctuation_frequency',
       'upper_case_frequency', 'lemma_per_token',
    # g4
    'total_negation_words', 'total_negated_context'
]
## Grupo 1 + Grupo 2 + Grupo 3: Aristotélico, sentimento específico de ódio e estatísticas do estilo de texto
att_1_2_3 = [ # g2
    'total_pos_w', 'total_pos_jj', 'total_pos_nn', 'total_neg_w',
       'total_neg_jj', 'total_neg_nn',  'total_pos_vb',
        'total_neg_vb',
       'hate_speech_terms_total', 
       'total_hate_jj', 'total_hate_nn', 'total_hate_rb', 'total_hate_vb',
       # g1
        'pos_sentiment_polarity', 'neu_sentiment_polarity', 'neg_sentiment_polarity',        
       'comp_sentiment_polarity',
       'pronoun_sent', 'future_tense', 'has_passive',
        'has_wh', 'subjecitivity', 'conditional',
       'numerical_nominal', 'organization_named', 'person_named',
       'has_complex_sent', 'sum_log_sent', 'third_p_count',
       'has_period',
       # g3
       'total_of_sentences',
       'char_mean_sentence', 'char_variance_sentence', 'total_char_text',
        'char_variance_word', 'punctuation_frequency',
       'upper_case_frequency', 'lemma_per_token'
]
## Grupo 1 + Grupo 2 + Grupo 4: Aristotélico, sentimento específico de ódio e contexto de negação
att_1_2_4 = [ # g2
    'total_pos_w', 'total_pos_jj', 'total_pos_nn', 'total_neg_w',
       'total_neg_jj', 'total_neg_nn',  'total_pos_vb',
        'total_neg_vb',
       'hate_speech_terms_total', 
       'total_hate_jj', 'total_hate_nn', 'total_hate_rb', 'total_hate_vb',
       # g1
        'pos_sentiment_polarity', 'neu_sentiment_polarity', 'neg_sentiment_polarity',        
       'comp_sentiment_polarity',
       'pronoun_sent', 'future_tense', 'has_passive',
        'has_wh', 'subjecitivity', 'conditional',
       'numerical_nominal', 'organization_named', 'person_named',
       'has_complex_sent', 'sum_log_sent', 'third_p_count',
       'has_period',
       # g4
       'total_negation_words', 'total_negated_context'
]
## Grupo 1 + Grupo 3 + Grupo 4: Aristotélico, estatísticas do estilo de texto e contexto de negação
att_1_3_4 = [ # g3
    'total_of_sentences',
       'char_mean_sentence', 'char_variance_sentence', 'total_char_text',
        'char_variance_word', 'punctuation_frequency',
       'upper_case_frequency', 'lemma_per_token',

        'total_pos_w',
        'total_pos_jj',
        'total_pos_nn',
        'total_neg_w',
        'total_neg_jj',
        'total_neg_nn',

       # g1
        'pos_sentiment_polarity', 'neu_sentiment_polarity', 'neg_sentiment_polarity',        
       'comp_sentiment_polarity',
       'pronoun_sent', 'future_tense', 'has_passive',
        'has_wh', 'subjecitivity', 'conditional',
       'numerical_nominal', 'organization_named', 'person_named',
       'has_complex_sent', 'sum_log_sent', 'third_p_count',
       'has_period', 
       # g4
       'total_negation_words', 'total_negated_context'
]
## Grupo 2 + Grupo 3 + Grupo 4: Analise de sentimento, discurso de ódio, estatísticas do estilo de texto e contexto de negação
att_2_3_4 = [ # g3
    'total_of_sentences',
       'char_mean_sentence', 'char_variance_sentence', 'total_char_text',
        'char_variance_word', 'punctuation_frequency',
       'upper_case_frequency', 'lemma_per_token',
       # g2
       'total_pos_w', 'total_pos_jj', 'total_pos_nn', 'total_neg_w',
       'total_neg_jj', 'total_neg_nn',  'total_pos_vb',
        'total_neg_vb',
       'hate_speech_terms_total', 
       'total_hate_jj', 'total_hate_nn', 'total_hate_rb', 'total_hate_vb',
       # g4
       'total_negation_words', 'total_negated_context'
]
## Grupo 1 + Grupo 2 + Grupo 3 + Grupo 4: Todas as meta-variáveis selecionadas
att_1_2_3_4 = [ # g1
      'pos_sentiment_polarity', 'neu_sentiment_polarity', 'neg_sentiment_polarity',        
       'comp_sentiment_polarity',
       'pronoun_sent', 'future_tense', 'has_passive',
        'has_wh', 'subjecitivity', 'conditional',
       'numerical_nominal', 'organization_named', 'person_named',
       'has_complex_sent', 'sum_log_sent', 'third_p_count',
       'has_period'  ,
       # g2
    'total_pos_w', 'total_pos_jj', 'total_pos_nn', 'total_neg_w',
       'total_neg_jj', 'total_neg_nn',  'total_pos_vb',
        'total_neg_vb',
       'hate_speech_terms_total', 
       'total_hate_jj', 'total_hate_nn', 'total_hate_rb', 'total_hate_vb',
       # g3
       'total_of_sentences',
       'char_mean_sentence', 'char_variance_sentence', 'total_char_text',
       
        'char_variance_word', 'punctuation_frequency',
       'upper_case_frequency', 'lemma_per_token',
       # g4
       'total_negation_words', 'total_negated_context'
]

# %%
## Criação e um dicionário com todas as combinações de meta-variáveis para simples iteração ##
feature_groups = {
    "Grupo 1 (Retórica)": g1_att,
    "Grupo 2 (Sentimento/Ódio)": g2_att,
    "Grupo 3 (Estatístico)": g3_att,
    "Grupo 4 (Contextual)": g4_att,

    "Grupos 1 + 2": att_1_2,
    "Grupos 1 + 3": att_1_3,
    "Grupos 1 + 4": att_1_4,
    "Grupos 2 + 3": att_2_3,
    "Grupos 2 + 4": att_2_4,
    "Grupos 3 + 4": att_3_4,

    "Grupos 1 + 2 + 3": att_1_2_3,
    "Grupos 1 + 2 + 4": att_1_2_4,
    "Grupos 1 + 3 + 4": att_1_3_4,
    "Grupos 2 + 3 + 4": att_2_3_4,
    
    "Todos os Grupos (1+2+3+4)": att_1_2_3_4
}

print(f"Dicionário contém {len(feature_groups)} combinações de meta-variáveis.")
for name, features in feature_groups.items():
    print(f"{name} tem {len(features)} meta-variáveis únicas.")
# Out:
# Dicionário contém 15 combinações de meta-variáveis.
# Grupo 1 (Retórica) tem 23 meta-variáveis únicas.
# Grupo 2 (Sentimento/Ódio) tem 13 meta-variáveis únicas.
# Grupo 3 (Estatístico) tem 8 meta-variáveis únicas.
# Grupo 4 (Contextual) tem 2 meta-variáveis únicas.
# Grupos 1 + 2 tem 30 meta-variáveis únicas.
# Grupos 1 + 3 tem 31 meta-variáveis únicas.
# Grupos 1 + 4 tem 25 meta-variáveis únicas.
# Grupos 2 + 3 tem 21 meta-variáveis únicas.
# Grupos 2 + 4 tem 15 meta-variáveis únicas.
# Grupos 3 + 4 tem 10 meta-variáveis únicas.
# Grupos 1 + 2 + 3 tem 38 meta-variáveis únicas.
# Grupos 1 + 2 + 4 tem 32 meta-variáveis únicas.
# Grupos 1 + 3 + 4 tem 33 meta-variáveis únicas.
# Grupos 2 + 3 + 4 tem 23 meta-variáveis únicas.
# Todos os Grupos (1+2+3+4) tem 40 meta-variáveis únicas.

# %%
#### Importações necessárias ####
import pandas as pd
import time
# Modelos de classificação e balanceamento
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from imblearn.over_sampling import SMOTE
# Métricas de avaliação
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

# %%
train = pd.read_pickle(r"..\data\processed\train.pkl")
test = pd.read_pickle(r"..\data\processed\test.pkl")

# %%
print("Número de instâncias na base de treino:", train.shape[0])
print(pd.DataFrame(train.persuasion.value_counts()))
# Out:
# Número de instâncias na base de treino: 7000
#             count
# persuasion
# 1            5736
# 0            1264

# %%
x_train = train.iloc[:, 2:]
y_train = train.iloc[:, 1]

sm = SMOTE(random_state = 2)
x_train, y_train = sm.fit_resample(x_train, y_train) # Balanceamento inicial da base de treinamento
x_test = test.iloc[:, 2:] # Variáveis preditoras da base de teste dependerão da combinação selecionada
y_test = test.iloc[:, 1] # Variável alvo fixa da base de teste

# %%
print("Número de instâncias na base de treino pós-SMOTE:", x_train.shape[0])
print(pd.DataFrame(y_train.value_counts()))
# Out:
# Número de instâncias na base de treino pós-SMOTE: 11472
#             count
# persuasion
# 1            5736
# 0            5736

# %%
models_to_run = {
    "Random Forest": RandomForestClassifier(criterion='gini', random_state=1),
    "Logistic Regression": LogisticRegression(solver='liblinear', random_state=1)
}

all_results = [] # Armazena resultados de todos os modelos e grupos

#### Início do loop de classificação ####
for group_name, feature_list in feature_groups.items():
    print(f"\n{'='*25}\nExecutando para o grupo: {group_name}\n{'='*25}")

    #### Seleção das meta-variáveis de cada grupo ####
    x_train_atts = x_train[feature_list]
    x_test_atts = x_test[feature_list]

    #### Itera sobre cada modelo (RF e LR) ####
    for model_name, model in models_to_run.items():
        print(f"  -> Treinando {model_name}...")
        
        # Treina o modelo
        start_time = time.time()
        model.fit(x_train_atts, y_train)
        training_time = time.time() - start_time
        
        # Faz as predições e gera o relatório e matriz de confusão
        pred = model.predict(x_test_atts)
        report = classification_report(y_test, pred, output_dict=True, zero_division=0)
        cmatrix = confusion_matrix(y_test, pred)

        # Salva as métricas e matriz de confusão na lista de resultados geral
        all_results.append({
            "Grupo de Meta-Variáveis": group_name,
            "Modelo Utilizado": model_name,
            "Acurácia": report['accuracy'],
            "F1-Macro": report['macro avg']['f1-score'], ## Retorna a média da F1-macro
            "Recall-Macro": report['macro avg']['recall'], ## Retorna a média da Recall-macro
            "F1 da Classe 1 (Persuasivo)": report['1']['f1-score'], ## F1 da classe positiva
            "F1 da Classe 0 (Não-Persuasivo)": report['0']['f1-score'], ## F1 da classe negativa
            "Matriz de Confusão": cmatrix,
            "Tempo de Treinamento": training_time
        })
# ------- Fim do loop de classificação -------

# Transforma a lista dos resultados em DataFrame para melhor visualização
results_df = pd.DataFrame(all_results)
# Out:
# ...
# Executando para o grupo: Grupo 1 (Retórica)
# ...
#   -> Treinando Random Forest...
#   -> Treinando Logistic Regression...
#
# ...
# Executando para o grupo: Grupo 2 (Sentimento/Ódio)
# ...
#   -> Treinando Random Forest...
#   -> Treinando Logistic Regression...
#
# ...
# Executando para o grupo: Grupo 3 (Estatístico)
# ...
#   -> Treinando Random Forest...
#   -> Treinando Logistic Regression...
#
# ...
# Executando para o grupo: Grupo 4 (Contextual)
# ...
#   -> Treinando Random Forest...
#   -> Treinando Logistic Regression...
#
# ...
# Executando para o grupo: Grupos 1 + 2
# ...
#   -> Treinando Random Forest...
#   -> Treinando Logistic Regression...
#
# ...
# Executando para o grupo: Grupos 1 + 3
# ...
#   -> Treinando Random Forest...
#   -> Treinando Logistic Regression...
#
# ...
# Executando para o grupo: Grupos 1 + 4
# ...
#   -> Treinando Random Forest...
#   -> Treinando Logistic Regression...
#
# ...
# Executando para o grupo: Grupos 2 + 3
# ...
#   -> Treinando Random Forest...
#   -> Treinando Logistic Regression...
#
# ...

# %%
# ------- Análise dos Resultados -------

# Ordena os resultados pelo F1-Macro em ordem decrescente e arredonda para 3 casas decimais
best_results = results_df.round(3).sort_values(by="F1-Macro", ascending=False)

print("🏆 Tabela de Classificação Final dos Modelos 🏆")
display(best_results)
# Out:
# 🏆 Tabela de Classificação Final dos Modelos 🏆
#       Grupo de Meta-Variáveis     Modelo Utilizado  Acurácia  F1-Macro  \
# 10               Grupos 1 + 3        Random Forest     0.837     0.701
# 20           Grupos 1 + 2 + 3        Random Forest     0.831     0.696
# 24           Grupos 1 + 3 + 4        Random Forest     0.837     0.696
# 28  Todos os Grupos (1+2+3+4)        Random Forest     0.831     0.688
# 22           Grupos 1 + 2 + 4        Random Forest     0.810     0.647
# 8                Grupos 1 + 2        Random Forest     0.811     0.646
# 0          Grupo 1 (Retórica)        Random Forest     0.805     0.645
# 29  Todos os Grupos (1+2+3+4)  Logistic Regression     0.761     0.644
# 27           Grupos 2 + 3 + 4  Logistic Regression     0.748     0.643
# 14               Grupos 2 + 3        Random Forest     0.801     0.640
# 26           Grupos 2 + 3 + 4        Random Forest     0.800     0.637
# 25           Grupos 1 + 3 + 4  Logistic Regression     0.748     0.633
# ...
